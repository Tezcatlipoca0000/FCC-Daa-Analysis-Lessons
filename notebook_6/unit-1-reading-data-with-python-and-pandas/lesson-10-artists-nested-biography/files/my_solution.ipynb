# %%
import pandas as pd
import json

# %%
with open('artists.json') as file:
    data = json.load(file)
print(data)
# Out:
# [{'name': 'Amedeo Modigliani', 'years': '1884 - 1920', 'genre': 'Expressionism', 'nationality': 'Italian', 'bio': [{'full name': 'Amedeo Clemente Modigliani', 'pronunciation': '[ameˈdɛːo modiʎˈʎaːni]', 'life span': '12 July 1884 – 24 January 1920', 'info': "was an Italian Jewish painter and sculptor who worked mainly in France. He is known for portraits and nudes in a modern style characterized by elongation of faces, necks, and figures that were not received well during his lifetime but later found acceptance. Modigliani spent his youth in Italy, where he studied the art of antiquity and the Renaissance. In 1906 he moved to Paris, where he came into contact with such artists as Pablo Picasso and Constantin Brâncuși. By 1912 Modigliani was exhibiting highly stylized sculptures with Cubists of the Section d'Or group at the Salon d'Automne.", 'wikipedia': 'http://en.wikipedia.org/wiki/Amedeo_Modigliani', 'paintings': 193}]}, {'name': 'Vasiliy Kandinskiy', 'years': '1866 - 1944', 'genre
# ...

# %%
artists = pd.json_normalize(data=data)
artists.head()
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
# %pip install flatten_json
from flatten_json import flatten
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for flatten_json: filename=flatten_json-0.1.13-py3-none-any.whl size=7978 sha256=fb0e5b0c9ff313cfab5f2743b65f34d39f19bf10746864a91bbf2b9e57ce8aec
#   Stored in directory: /home/codespace/.cache/pip/wheels/91/53/73/b95859198efda46a5e2b50d7d139e9f1042c8ff3210700b999
# Successfully built flatten_json
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
flat_artists = [flatten(d, '.') for d in data]
artists = pd.json_normalize(flat_artists)
artists.head()
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                      bio.0.full name  \
# 0                         Amedeo Clemente Modigliani
# 1                     Wassily Wassilyevich Kandinsky
# 2  Diego María de la Concepción Juan Nepomuceno E...
# 3                                 Oscar-Claude Monet
# 4                    René François Ghislain Magritte
#
#                                  bio.0.pronunciation  \
# 0                             [ameˈdɛːo modiʎˈʎaːni]
# 1  Васи́лий Васи́льевич Канди́нский, tr. Vasíliy ...
# ...

# %%
biography = pd.json_normalize(data=data, record_path='bio', meta='name')
biography.head()
# Out:
#                                            full name  \
# 0                         Amedeo Clemente Modigliani
# 1                     Wassily Wassilyevich Kandinsky
# 2  Diego María de la Concepción Juan Nepomuceno E...
# 3                                 Oscar-Claude Monet
# 4                    René François Ghislain Magritte
#
#                                        pronunciation  \
# 0                             [ameˈdɛːo modiʎˈʎaːni]
# 1  Васи́лий Васи́льевич Канди́нский, tr. Vasíliy ...
# 2                                   [ˈdjeɣo riˈβeɾa]
# 3                                        [klod mɔnɛ]
# 4                        [ʁəne fʁɑ̃swa ɡilɛ̃ maɡʁit]
#
#                                            life span  \
# 0                     12 July 1884 – 24 January 1920
# 1  16 December [O.S. 4 December] 1866 – 13 Decemb...
# 2               December 8, 1886 – November 24, 1957
# 3                 14 November 1840 – 5 December 1926
# ...
